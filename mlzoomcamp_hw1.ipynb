# %% [markdown]
# <a href="https://colab.research.google.com/github/difurka/mlbookcamp_learning/blob/main/mlzoomcamp_hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Out:
# --2023-09-18 06:51:41--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.009s
#
# 2023-09-18 06:51:41 (149 MB/s) - ‘housing.csv’ saved [1423529/1423529]

# %%
df = pd.read_csv('/content/housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# median_house_value     3842
# ocean_proximity           5
# dtype: int64

# %%
df['median_house_value'].describe()
# Out:
# count     20640.000000
# mean     206855.816909
# std      115395.615874
# min       14999.000000
# 25%      119600.000000
# 50%      179700.000000
# 75%      264725.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
df[df['ocean_proximity']=='NEAR BAY']['median_house_value'].mean()
# Out:
# 259212.31179039303

# %%
df.groupby('ocean_proximity').mean()
# Out:
#                   longitude   latitude  housing_median_age  total_rooms  \
# ocean_proximity
# <1H OCEAN       -118.847766  34.560577           29.279225  2628.343586
# INLAND          -119.732990  36.731829           24.271867  2717.742787
# ISLAND          -118.354000  33.358000           42.400000  1574.600000
# NEAR BAY        -122.260694  37.801057           37.730131  2493.589520
# NEAR OCEAN      -119.332555  34.738439           29.347254  2583.700903
#
#                  total_bedrooms   population  households  median_income  \
# ocean_proximity
# <1H OCEAN            546.539185  1520.290499  517.744965       4.230682
# INLAND               533.881619  1391.046252  477.447565       3.208996
# ISLAND               420.400000   668.000000  276.600000       2.744420
# NEAR BAY             514.182819  1230.317467  488.616157       4.172885
# NEAR OCEAN           538.615677  1354.008653  501.244545       4.005785
#
#                  median_house_value
# ocean_proximity
# ...

# %%
me = df['total_bedrooms'].mean()
me
# Out:
# 537.8705525375618

# %%
df['total_bedrooms'].fillna(me, inplace=True)
me2 = df['total_bedrooms'].mean()
me2
# Out:
# 537.8705525375617

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
X = df[df['ocean_proximity']=='ISLAND'][['housing_median_age', 'total_rooms', 'total_bedrooms']]

# %%
X*X
# Out:
#       housing_median_age  total_rooms  total_bedrooms
# 8314                27.0       1675.0           521.0
# 8315                52.0       2359.0           591.0
# 8316                52.0       2127.0           512.0
# 8317                52.0        996.0           264.0
# 8318                29.0        716.0           214.0

# %%
X1 = X.T.dot(X)

# %%
import numpy as np
X2 = np.linalg.inv(X1)

# %%
y = np.array([950, 1300, 800, 1000, 1300])

# %%
w = X2.dot(X.T).dot(y)
w
# Out:
# array([23.12330961, -1.48124183,  5.69922946])
